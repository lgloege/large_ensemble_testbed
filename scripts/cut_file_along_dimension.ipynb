# %% [markdown]
# # cut file along dimension
# cuts a file into many files along some dimension

# %%
import os
import shutil
import numpy as np
import xarray as xr
import pandas as pd

# %% [markdown]
# # Split files

# %%
# load data
data_dir='/local/data/artemis/workspace/gloege/data/MPI_GE/wind10'
ds = xr.open_dataset(f'{data_dir}/hcp85_woa13cp_1850_2099_ens_1-100.wind10.nc')

# Cut data
for ens in ds.ens.values:
    # output file
    fl=f'hcp850{ens+1:03d}_wind10_woa13cp_2d_mm_1850_2099.nc'
    print(fl)
    
    # Save to netcdf
    ds.sel(ens=0).to_netcdf(f'{data_dir}/{fl}')
# Out:
# hcp850001_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850002_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850003_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850004_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850005_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850006_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850007_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850008_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850009_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850010_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850011_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850012_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850013_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850014_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850015_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850016_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850017_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850018_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850019_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850020_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850021_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850022_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850023_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850024_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850025_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850026_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850027_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850028_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850029_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850030_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850031_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850032_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850033_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850034_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850035_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850036_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850037_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850038_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850039_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850040_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850041_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850042_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850043_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850044_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850045_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850046_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850047_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850048_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850049_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850050_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850051_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850052_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850053_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850054_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850055_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850056_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850057_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850058_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850059_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850060_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850061_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850062_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850063_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850064_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850065_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850066_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850067_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850068_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850069_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850070_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850071_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850072_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850073_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850074_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850075_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850076_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850077_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850078_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850079_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850080_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850081_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850082_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850083_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850084_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850085_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850086_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850087_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850088_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850089_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850090_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850091_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850092_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850093_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850094_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850095_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850096_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850097_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850098_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850099_wind10_woa13cp_2d_mm_1850_2099.nc
# hcp850100_wind10_woa13cp_2d_mm_1850_2099.nc

# %% [markdown]
# # Process Files
# You will need to change variable names at various places here

# %%
# define ensemble length
for ens in np.arange(1,101):
    # define directories
    in_dir = '/local/data/artemis/workspace/gloege/data/MPI_GE/aps'

    # define files
    ifile = f'{in_dir}/raw/hcp850{ens:03d}_aps_woa13cp_2d_mm_1850_2099.nc'
    ofile = f'{in_dir}/processed/pATM_2D_mon_MPI{ens:03d}_1x1_198201-201701.nc'
    print(f'{ifile}')

    # Load file
    ds = xr.open_dataset(ifile)

    # Define date range
    dates = pd.date_range(start='1850-01-01T00:00:00.000000000', 
                          end='2099-12-01T00:00:00.000000000',freq='MS')+ np.timedelta64(14, 'D')

    # make dates be datetime64
    ds['time'] = dates

    # convert pascal to atmosphere
    Pa_in_atm = 101325
    ds['aps'] = ds['aps']/Pa_in_atm
    ds.aps.attrs = {'long_name':'surface pressure', 
                    'units':'atmospheres'}

    # rename variables
    ds = ds.rename({'lon':'xlon', 
               'lat':'ylat', 
               'aps':'pATM'}).sel(time=slice('1982-01','2017-01'))
    
    # Save netcdf
    ds.to_netcdf(f'{ofile}')
# Out:
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850001_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850002_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850003_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850004_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850005_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850006_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850007_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850008_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850009_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850010_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850011_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850012_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850013_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850014_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850015_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850016_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850017_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850018_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850019_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850020_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850021_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850022_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850023_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850024_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850025_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850026_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850027_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850028_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850029_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850030_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850031_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850032_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850033_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850034_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850035_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850036_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850037_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850038_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850039_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850040_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850041_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850042_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850043_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850044_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850045_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850046_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850047_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850048_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850049_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850050_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850051_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850052_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850053_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850054_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850055_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850056_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850057_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850058_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850059_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850060_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850061_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850062_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850063_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850064_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850065_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850066_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850067_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850068_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850069_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850070_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850071_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850072_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850073_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850074_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850075_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850076_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850077_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850078_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850079_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850080_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850081_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850082_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850083_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850084_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850085_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850086_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850087_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850088_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850089_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850090_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850091_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850092_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850093_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850094_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850095_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850096_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850097_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850098_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850099_aps_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/aps/raw/hcp850100_aps_woa13cp_2d_mm_1850_2099.nc

# %% [markdown]
# ## Process siconc

# %%
# define ensemble length
for ens in np.arange(1,101):
    # define directories
    in_dir = '/local/data/artemis/workspace/gloege/data/MPI_GE/siconc'

    # define files
    ifile = f'{in_dir}/raw/hcp850{ens:03d}_siconc_woa13cp_2d_mm_1850_2099.nc'
    ofile = f'{in_dir}/processed/iceFrac_2D_mon_MPI{ens:03d}_1x1_198201-201701.nc'
    print(f'{ifile}')

    # Load file
    ds = xr.open_dataset(ifile)
    
    # Drop un-needed variables 
    ds = ds.squeeze().drop('depth')
    
    # Define date range
    dates = pd.date_range(start='1850-01-01T00:00:00.000000000', 
                          end='2099-12-01T00:00:00.000000000',freq='MS')+ np.timedelta64(14, 'D')

    # make dates be datetime64
    ds['time'] = dates

    # rename variables
    ds = ds.rename({'lon':'xlon', 
                    'lat':'ylat', 
                    'siconc':'iceFrac'}).sel(time=slice('1982-01','2017-01'))
    
    # Save netcdf
    ds.to_netcdf(f'{ofile}')
# Out:
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850001_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850002_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850003_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850004_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850005_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850006_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850007_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850008_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850009_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850010_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850011_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850012_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850013_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850014_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850015_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850016_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850017_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850018_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850019_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850020_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850021_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850022_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850023_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850024_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850025_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850026_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850027_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850028_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850029_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850030_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850031_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850032_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850033_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850034_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850035_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850036_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850037_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850038_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850039_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850040_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850041_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850042_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850043_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850044_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850045_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850046_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850047_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850048_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850049_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850050_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850051_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850052_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850053_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850054_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850055_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850056_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850057_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850058_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850059_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850060_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850061_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850062_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850063_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850064_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850065_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850066_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850067_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850068_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850069_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850070_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850071_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850072_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850073_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850074_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850075_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850076_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850077_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850078_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850079_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850080_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850081_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850082_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850083_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850084_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850085_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850086_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850087_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850088_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850089_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850090_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850091_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850092_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850093_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850094_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850095_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850096_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850097_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850098_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850099_siconc_woa13cp_2d_mm_1850_2099.nc
# /local/data/artemis/workspace/gloege/data/MPI_GE/siconc/raw/hcp850100_siconc_woa13cp_2d_mm_1850_2099.nc

# %% [markdown]
# # Move files

# %%
# Members list
mpi_members = ['006', '009', '014', '020', '022',
              '024', '025', '027', '038', '043',
              '045', '046', '057', '060', '064',
              '070', '075', '077', '078', '080',
              '081', '083', '091', '095', '098']

# %%
for mem in mpi_members:
    print(mem)
    
    # define directories 
    in_dir = '/local/data/artemis/workspace/gloege/data/MPI_GE/siconc'
    out_dir = f'/local/data/artemis/workspace/gloege/SOCAT-LE/data/raw/large_ensembles/MPI/member_{mem}'

    # define files
    ifile = f'{in_dir}/processed/iceFrac_2D_mon_MPI{mem}_1x1_198201-201701.nc'
    ofile = f'{out_dir}/iceFrac_2D_mon_MPI{mem}_1x1_198201-201701.nc'

    # move files
    shutil.copy(f'{ifile}', f'{ofile}')
# Out:
# 006
# 009
# 014
# 020
# 022
# 024
# 025
# 027
# 038
# 043
# 045
# 046
# 057
# 060
# 064
# 070
# 075
# 077
# 078
# 080
# 081
# 083
# 091
# 095
# 098

# %%
for mem in mpi_members:
    print(mem)
    
    # define directories 
    in_dir = '/local/data/artemis/workspace/gloege/data/MPI_GE/aps'
    out_dir = f'/local/data/artemis/workspace/gloege/SOCAT-LE/data/raw/large_ensembles/MPI/member_{mem}'

    # define files
    ifile = f'{in_dir}/processed/pATM_2D_mon_MPI{mem}_1x1_198201-201701.nc'
    ofile = f'{out_dir}/pATM_2D_mon_MPI{mem}_1x1_198201-201701.nc'

    # move files
    shutil.copy(f'{ifile}', f'{ofile}')
# Out:
# 006
# 009
# 014
# 020
# 022
# 024
# 025
# 027
# 038
# 043
# 045
# 046
# 057
# 060
# 064
# 070
# 075
# 077
# 078
# 080
# 081
# 083
# 091
# 095
# 098

# %%
for mem in mpi_members:
    print(mem)
    
    # define directories 
    in_dir = '/local/data/artemis/workspace/gloege/data/MPI_GE/wind10'
    out_dir = f'/local/data/artemis/workspace/gloege/SOCAT-LE/data/raw/large_ensembles/MPI/member_{mem}'

    # define files
    ifile = f'{in_dir}/processed/U10_2D_mon_MPI{mem}_1x1_198201-201701.nc'
    ofile = f'{out_dir}/U10_2D_mon_MPI{mem}_1x1_198201-201701.nc'

    # move files
    shutil.copy(f'{ifile}', f'{ofile}')
# Out:
# 006
# 009
# 014
# 020
# 022
# 024
# 025
# 027
# 038
# 043
# 045
# 046
# 057
# 060
# 064
# 070
# 075
# 077
# 078
# 080
# 081
# 083
# 091
# 095
# 098
