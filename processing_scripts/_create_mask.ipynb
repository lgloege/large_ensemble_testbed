# %% [markdown]
# # Create data mask
# This uses a simple mask from SOMFFN to block out artic and ice regions

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
fl = '/local/data/artemis/workspace/gloege/SOCAT-LE/data/clean/mask_somffn.nc'
ds = xr.open_dataset(fl)

# %%
plt.pcolor(ds['mask'])

# %%
ds2 = xr.open_dataset('/local/data/artemis/workspace/gloege/SOCAT-LE/data/test.nc', decode_times=False)

# %%
plt.pcolor(ds2['pCO2'].max('time'))

# %% [markdown]
# # use to mask on cheyenne
# `cdo mul mask_somffn.nc  CESM-hindcast_pCO2_1x1_194801-201512.nc test.nc`

# %%
data_dir='/local/data/artemis/workspace/gloege/LDEO-FFN/data/hindcast'

# %%
fl = f'{data_dir}/CESM-hindcast_pCO2_1x1_198201-201512.nc'
ds = xr.open_dataset(fl, decode_times=False)
plt.pcolor(ds['pCO2'].mean('time'))
plt.colorbar()

# %%
fl = '/local/data/artemis/workspace/gloege/SOCAT-LE/data/raw/interpolated/carboScope/prelim/mu1.0_300_pCO2_asis+1982-2017.nc'

# %%
ds=xr.open_dataset(fl)

# %%
area = ds['dxyp']

# %%
land = ds['area']

# %%
frac = land/area

# %%
ocn = frac[1,:,:]
mask = (ocn.where(ocn>=0.1))
plt.pcolor(ds['lon'],ds['lat'],mask)

# %%
mask = (ocn-1).where(ocn>=0)
# Out:
#   File "<ipython-input-69-e7dc0e95f8cb>", line 1
#     mask = (ocn-1).where(ocn>=0))
#                                 ^
# SyntaxError: invalid syntax
